# %% [markdown]
# ## TensorBoard Demo
# ### Import the Tensorflow Framework

# %%
import tensorflow as tf

# %% [markdown]
# ### Use MNIST dataset and define the model

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

def create_model():
    return tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
  ])

# %% [markdown]
# ### Compile and add the Tensorboard callback

# %%
import datetime
model = create_model()
model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

model.fit(x = x_train, y = y_train, epochs = 5, validation_data = (x_test, y_test), callbacks = [tensorboard_callback])
# Out:
# Epoch 1/5
#    1/1875 [..............................] - ETA: 0s - loss: 2.2430 - accuracy: 0.2188WARNING:tensorflow:From C:\Users\Pranav\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# ...
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2190 - accuracy: 0.9352 - val_loss: 0.1122 - val_accuracy: 0.9657
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0979 - accuracy: 0.9697 - val_loss: 0.0790 - val_accuracy: 0.9754
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0698 - accuracy: 0.9779 - val_loss: 0.0668 - val_accuracy: 0.9790
# Epoch 4/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0528 - accuracy: 0.9836 - val_loss: 0.0646 - val_accuracy: 0.9798
# Epoch 5/5
# ...

# %% [markdown]
# ### Enter this on anaconda command prompt and open browser and hit the url http://localhost:6006/
# ### Command: tensorboard --logdir logs/fit

# %% [markdown]
# ## Given below is the screen shot of vizualization of accuracy and loss metrics, it is updated according to the callbacks

# %% [markdown]
# ![Tensorboard%20-%20Metrics.png](attachment:Tensorboard%20-%20Metrics.png)

# %% [markdown]
# ## This is the histogram which shows the distribution of weights and biases per layer

# %% [markdown]
# ![Tensorboard%20-%20Histogram.png](attachment:Tensorboard%20-%20Histogram.png)
